# %% [markdown]
# ##### Trying the BellKor's Pragmatic Chaos algorithm

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.metrics import r2_score

# %%
from surprise import Dataset, Reader
from surprise import SVD, SVDpp, accuracy
from surprise.model_selection import train_test_split, GridSearchCV

# %%
from collections import defaultdict

# %%
df = pd.read_csv('/Users/zachariamwaura/Documents/Flatiron/Phase_4/Phase_4_Project/DATA/ratings.csv', index_col=False)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33832162 entries, 0 to 33832161
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   userId     int64
#  1   movieId    int64
#  2   rating     float64
#  3   timestamp  int64
# dtypes: float64(1), int64(3)
# memory usage: 1.0 GB

# %%
df_sample = df.sample(n=100000, random_state=1)
df_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100000 entries, 33179850 to 21265524
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100000 non-null  int64
#  1   movieId    100000 non-null  int64
#  2   rating     100000 non-null  float64
#  3   timestamp  100000 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.8 MB

# %%
df_sample['userId'].value_counts()
# Out:
# userId
# 189614    105
# 207216     40
# 76618      30
# 48766      30
# 233891     29
#          ...
# 219707      1
# 313398      1
# 219351      1
# 257006      1
# 207550      1
# Name: count, Length: 61540, dtype: int64

# %%
#df_sample = df_sample.drop('timestamp', axis=1)

# %% [markdown]
# --------------

# %%
reader = Reader(rating_scale=(1,5))

# %%
data = Dataset.load_from_df(df_sample[['userId', 'movieId', 'rating']], reader)

# %%
trainset, testset = train_test_split(data, test_size=.2, random_state=42)

# %% [markdown]
# -----------------

# %%
svd = SVD()
svd.fit(trainset)

# %%
svdpp = SVDpp()
svdpp.fit(trainset)

# %%
svd_predictions = svd.test(testset)
svdpp_predictions = svdpp.test(testset)

# %%
svd_rmse = accuracy.rmse(svd_predictions)
svdpp_rmse = accuracy.rmse(svdpp_predictions)
# Out:
# RMSE: 0.9865
# RMSE: 0.9863

# %%
print(f"SVD RMSE: {svd_rmse}")
print(f"SVD++ RMSE: {svdpp_rmse}")
# Out:
# SVD RMSE: 0.9864541434721968
# SVD++ RMSE: 0.9862737619811071

# %% [markdown]
# --------------

# %%
df_sample.sample(n=1)
# Out:
#           userId  movieId  rating  timestamp
# 29264832  285882      173     3.0  835627114

# %%
svd_predictions
# Out:
# [Prediction(uid=320615, iid=457, r_ui=4.0, est=3.9543200042948774, details={'was_impossible': False}),
#  Prediction(uid=85899, iid=48516, r_ui=4.0, est=3.9747269375406638, details={'was_impossible': False}),
#  Prediction(uid=16521, iid=4896, r_ui=3.5, est=3.4102952265844455, details={'was_impossible': False}),
#  Prediction(uid=199688, iid=67255, r_ui=4.5, est=3.5513593898113265, details={'was_impossible': False}),
#  Prediction(uid=274004, iid=1672, r_ui=4.0, est=3.7256412372523626, details={'was_impossible': False}),
#  Prediction(uid=276446, iid=2792, r_ui=4.0, est=3.214325241658067, details={'was_impossible': False}),
#  Prediction(uid=180788, iid=3897, r_ui=3.0, est=3.7198311202390144, details={'was_impossible': False}),
#  Prediction(uid=276405, iid=135885, r_ui=3.0, est=3.4154138091163726, details={'was_impossible': False}),
#  Prediction(uid=302622, iid=1375, r_ui=3.0, est=3.304457732072382, details={'was_impossible': False}),
#  Prediction(uid=214968, iid=4886, r_ui=3.0, est=3.755268744294304, details={'was_impossible': False}),
#  Prediction(uid=211668, iid=593, r_ui=3.0, est=4.1080428687012995, details={'was_impossible': False}),
#  Prediction(uid=286005, iid=6373, r_ui=3.5, est=3.2173899750970514, details={'was_impossible': False}),
#  Prediction(uid=29800, iid=2324, r_ui=4.5, est=4.179517712224334, details={'was_impossible': False}),
#  Prediction(uid=237691, iid=551, r_ui=5.0, est=3.6642302291260926, details={'was_impossible': False}),
#  Prediction(uid=267129, iid=593, r_ui=3.0, est=4.1080428687012995, details={'was_impossible': False}),
#  Prediction(uid=183877, iid=1304, r_ui=3.0, est=3.928492839101038, details={'was_impossible': False}),
#  Prediction(uid=136561, iid=1608, r_ui=3.0, est=3.1500130611733845, details={'was_impossible': False}),
#  Prediction(uid=311383, iid=122886, r_ui=5.0, est=3.673396641882264, details={'was_impossible': False}),
#  Prediction(uid=60650, iid=46967, r_ui=4.0, est=3.246948188810369, details={'was_impossible': False}),
#  Prediction(uid=253249, iid=99149, r_ui=5.0, est=3.7348519558064908, details={'was_impossible': False}),
#  Prediction(uid=98290, iid=3556, r_ui=4.5, est=3.514005083001882, details={'was_impossible': False}),
#  Prediction(uid=122715, iid=112623, r_ui=4.0, est=3.4487058953516287, details={'was_impossible': False}),
#  Prediction(uid=47929, iid=204872, r_ui=4.0, est=3.54615, details={'was_impossible': False}),
#  Prediction(uid=57352, iid=79132, r_ui=4.0, est=4.226411216305676, details={'was_impossible': False}),
#  Prediction(uid=41638, iid=4011, r_ui=3.0, est=4.135632374734414, details={'was_impossible': False}),
#  Prediction(uid=81591, iid=3101, r_ui=4.0, est=3.2891407848131498, details={'was_impossible': False}),
#  Prediction(uid=3107, iid=1552, r_ui=4.0, est=3.320214680159417, details={'was_impossible': False}),
#  Prediction(uid=296948, iid=1480, r_ui=2.0, est=3.3900882025407704, details={'was_impossible': False}),
#  Prediction(uid=226916, iid=227, r_ui=3.0, est=3.2659574880809124, details={'was_impossible': False}),
#  Prediction(uid=13556, iid=278312, r_ui=1.0, est=3.2528400033498888, details={'was_impossible': False}),
#  Prediction(uid=220499, iid=33750, r_ui=2.5, est=3.5000547967073103, details={'was_impossible': False}),
#  Prediction(uid=159728, iid=6155, r_ui=2.0, est=3.1170390746196643, details={'was_impossible': False}),
#  Prediction(uid=278423, iid=910, r_ui=4.0, est=3.871239286992139, details={'was_impossible': False}),
#  Prediction(uid=207824, iid=11, r_ui=3.0, est=3.818142120954269, details={'was_impossible': False}),
#  Prediction(uid=308118, iid=3000, r_ui=5.0, est=4.127742986043406, details={'was_impossible': False}),
#  Prediction(uid=131962, iid=135567, r_ui=4.0, est=2.765195744498579, details={'was_impossible': False}),
#  Prediction(uid=68030, iid=82848, r_ui=3.5, est=3.3820547466864532, details={'was_impossible': False}),
#  Prediction(uid=260583, iid=5226, r_ui=2.0, est=3.055568565486968, details={'was_impossible': False}),
#  Prediction(uid=178757, iid=3753, r_ui=3.5, est=3.5335928844821347, details={'was_impossible': False}),
#  Prediction(uid=107064, iid=1261, r_ui=4.0, est=3.916932051026436, details={'was_impossible': False}),
#  Prediction(uid=27479, iid=38038, r_ui=0.5, est=3.5293352471098616, details={'was_impossible': False}),
#  Prediction(uid=144351, iid=3114, r_ui=1.0, est=3.8275888446685316, details={'was_impossible': False}),
#  Prediction(uid=190932, iid=4896, r_ui=3.0, est=3.514401849032955, details={'was_impossible': False}),
#  Prediction(uid=78134, iid=2253, r_ui=1.5, est=2.9776514190471253, details={'was_impossible': False}),
#  Prediction(uid=190166, iid=2728, r_ui=4.0, est=3.6335124608002713, details={'was_impossible': False}),
#  Prediction(uid=226325, iid=3977, r_ui=5.0, est=2.8195486069521736, details={'was_impossible': False}),
#  Prediction(uid=173950, iid=4520, r_ui=2.0, est=3.4293212979099903, details={'was_impossible': False}),
#  Prediction(uid=112206, iid=91658, r_ui=4.0, est=3.645576752962345, details={'was_impossible': False}),
#  Prediction(uid=238796, iid=5069, r_ui=3.5, est=3.442337317700224, details={'was_impossible': False}),
#  Prediction(uid=42337, iid=3698, r_ui=3.0, est=3.3951254620168028, details={'was_impossible': False}),
#  Prediction(uid=226631, iid=527, r_ui=4.5, est=4.268635707468755, details={'was_impossible': False}),
#  Prediction(uid=87478, iid=256, r_ui=2.0, est=2.9667512862387366, details={'was_impossible': False}),
#  Prediction(uid=245230, iid=200818, r_ui=3.0, est=3.4760195958615356, details={'was_impossible': False}),
#  Prediction(uid=157591, iid=2997, r_ui=4.0, est=4.212718577464528, details={'was_impossible': False}),
#  Prediction(uid=157202, iid=1699, r_ui=5.0, est=3.4312738323636904, details={'was_impossible': False}),
#  Prediction(uid=26794, iid=4214, r_ui=4.0, est=3.2956977957998745, details={'was_impossible': False}),
#  Prediction(uid=323085, iid=1265, r_ui=3.0, est=3.8847552467488704, details={'was_impossible': False}),
#  Prediction(uid=321251, iid=1953, r_ui=4.5, est=3.6520607210409644, details={'was_impossible': False}),
#  Prediction(uid=277791, iid=79132, r_ui=4.0, est=4.269775884880388, details={'was_impossible': False}),
#  Prediction(uid=289167, iid=912, r_ui=4.0, est=4.101785838437318, details={'was_impossible': False}),
#  Prediction(uid=158849, iid=953, r_ui=3.5, est=4.103018619080778, details={'was_impossible': False}),
#  Prediction(uid=295694, iid=3156, r_ui=4.0, est=3.3499035906239443, details={'was_impossible': False}),
#  Prediction(uid=131595, iid=318, r_ui=4.0, est=4.462516639365968, details={'was_impossible': False}),
#  Prediction(uid=325881, iid=788, r_ui=2.5, est=2.822518181974343, details={'was_impossible': False}),
#  Prediction(uid=3494, iid=2502, r_ui=4.0, est=4.359960701029698, details={'was_impossible': False}),
#  Prediction(uid=181945, iid=2648, r_ui=5.0, est=3.807748419957407, details={'was_impossible': False}),
#  Prediction(uid=279806, iid=3967, r_ui=4.5, est=3.482265239977036, details={'was_impossible': False}),
#  Prediction(uid=20932, iid=48780, r_ui=5.0, est=3.873570496068837, details={'was_impossible': False}),
#  Prediction(uid=144351, iid=52694, r_ui=5.0, est=3.114513256430649, details={'was_impossible': False}),
#  Prediction(uid=176334, iid=296, r_ui=5.0, est=4.191082044961874, details={'was_impossible': False}),
#  Prediction(uid=239937, iid=918, r_ui=4.0, est=3.724907162603473, details={'was_impossible': False}),
#  Prediction(uid=317166, iid=2144, r_ui=4.5, est=3.839766694464927, details={'was_impossible': False}),
#  Prediction(uid=36127, iid=97921, r_ui=2.0, est=3.545951414701605, details={'was_impossible': False}),
#  Prediction(uid=292385, iid=2804, r_ui=4.0, est=3.859333644333971, details={'was_impossible': False}),
#  Prediction(uid=243914, iid=2616, r_ui=1.5, est=2.6810514465632562, details={'was_impossible': False}),
#  Prediction(uid=200656, iid=2694, r_ui=2.0, est=2.8331619296267707, details={'was_impossible': False}),
#  Prediction(uid=5659, iid=4733, r_ui=4.0, est=3.4940040113880446, details={'was_impossible': False}),
#  Prediction(uid=105342, iid=2716, r_ui=5.0, est=3.934817513042306, details={'was_impossible': False}),
#  Prediction(uid=131287, iid=160, r_ui=3.0, est=2.3004813747278745, details={'was_impossible': False}),
#  Prediction(uid=202140, iid=1923, r_ui=2.5, est=3.588847637024588, details={'was_impossible': False}),
#  Prediction(uid=27969, iid=383, r_ui=4.5, est=3.5653287716280606, details={'was_impossible': False}),
#  Prediction(uid=124724, iid=27706, r_ui=3.5, est=3.021913902980736, details={'was_impossible': False}),
#  Prediction(uid=166725, iid=2288, r_ui=4.5, est=3.8891813227632026, details={'was_impossible': False}),
#  Prediction(uid=50844, iid=5267, r_ui=3.0, est=3.7180328366406488, details={'was_impossible': False}),
#  Prediction(uid=256871, iid=25930, r_ui=4.5, est=3.515355685965531, details={'was_impossible': False}),
#  Prediction(uid=60761, iid=2288, r_ui=5.0, est=4.086919802709962, details={'was_impossible': False}),
#  Prediction(uid=236214, iid=54286, r_ui=3.5, est=3.899835654878356, details={'was_impossible': False}),
#  Prediction(uid=110897, iid=6016, r_ui=4.5, est=4.082099108728828, details={'was_impossible': False}),
#  Prediction(uid=36249, iid=45722, r_ui=3.5, est=3.4652127942853324, details={'was_impossible': False}),
#  Prediction(uid=273034, iid=541, r_ui=4.0, est=4.078861174011186, details={'was_impossible': False}),
#  Prediction(uid=174332, iid=1517, r_ui=5.0, est=3.515679244293822, details={'was_impossible': False}),
#  Prediction(uid=154467, iid=122264, r_ui=5.0, est=3.54615, details={'was_impossible': False}),
#  Prediction(uid=84366, iid=5507, r_ui=3.0, est=3.033860297564022, details={'was_impossible': False}),
#  Prediction(uid=194341, iid=149, r_ui=3.5, est=3.7119418589683706, details={'was_impossible': False}),
#  Prediction(uid=273127, iid=111375, r_ui=5.0, est=3.576979846214065, details={'was_impossible': False}),
#  Prediction(uid=94126, iid=46972, r_ui=0.5, est=3.1281972989470423, details={'was_impossible': False}),
#  Prediction(uid=116913, iid=5312, r_ui=3.0, est=2.8373952928587896, details={'was_impossible': False}),
#  Prediction(uid=235618, iid=3578, r_ui=4.0, est=3.8855670909214846, details={'was_impossible': False}),
#  Prediction(uid=127625, iid=317, r_ui=0.5, est=3.3006842408325174, details={'was_impossible': False}),
#  Prediction(uid=43223, iid=4262, r_ui=5.0, est=4.1325404428650945, details={'was_impossible': False}),
#  Prediction(uid=120783, iid=87483, r_ui=3.0, est=3.5398607341201833, details={'was_impossible': False}),
#  Prediction(uid=257949, iid=97306, r_ui=4.0, est=3.7517484859945007, details={'was_impossible': False}),
#  Prediction(uid=107366, iid=111362, r_ui=4.0, est=3.3965666673602377, details={'was_impossible': False}),
#  Prediction(uid=119311, iid=318, r_ui=3.0, est=4.462516639365968, details={'was_impossible': False}),
#  Prediction(uid=31291, iid=2390, r_ui=3.0, est=3.5062285194029505, details={'was_impossible': False}),
#  Prediction(uid=44697, iid=589, r_ui=4.5, est=3.6852491260609477, details={'was_impossible': False}),
#  Prediction(uid=121219, iid=60069, r_ui=4.0, est=4.017591572531207, details={'was_impossible': False}),
#  Prediction(uid=209234, iid=70286, r_ui=4.0, est=3.6372151346655057, details={'was_impossible': False}),
#  Prediction(uid=66697, iid=1136, r_ui=4.0, est=4.226828608200748, details={'was_impossible': False}),
#  Prediction(uid=251619, iid=1126, r_ui=1.0, est=3.235533274813655, details={'was_impossible': False}),
#  Prediction(uid=25549, iid=4875, r_ui=2.0, est=3.54615, details={'was_impossible': False}),
#  Prediction(uid=38790, iid=5601, r_ui=3.0, est=3.459188819719121, details={'was_impossible': False}),
#  Prediction(uid=16884, iid=2287, r_ui=5.0, est=3.6544241386148366, details={'was_impossible': False}),
#  Prediction(uid=192035, iid=215, r_ui=3.0, est=4.236660049648462, details={'was_impossible': False}),
#  Prediction(uid=316551, iid=8360, r_ui=3.5, est=3.5398106464667354, details={'was_impossible': False}),
#  Prediction(uid=148471, iid=5881, r_ui=4.0, est=3.5592873100071807, details={'was_impossible': False}),
#  Prediction(uid=106257, iid=3175, r_ui=4.0, est=3.343176175268553, details={'was_impossible': False}),
#  Prediction(uid=60701, iid=66934, r_ui=5.0, est=3.3777537133821576, details={'was_impossible': False}),
#  Prediction(uid=92011, iid=57504, r_ui=0.5, est=3.8117186996558177, details={'was_impossible': False}),
#  Prediction(uid=215001, iid=51091, r_ui=3.5, est=3.64534797198227, details={'was_impossible': False}),
#  Prediction(uid=11717, iid=2104, r_ui=3.5, est=3.8079598391948974, details={'was_impossible': False}),
#  Prediction(uid=99626, iid=1266, r_ui=5.0, est=3.6187478167945417, details={'was_impossible': False}),
#  Prediction(uid=106455, iid=780, r_ui=4.0, est=3.5156600052959472, details={'was_impossible': False}),
#  Prediction(uid=130516, iid=1193, r_ui=5.0, est=4.307972428635457, details={'was_impossible': False}),
#  Prediction(uid=302445, iid=50872, r_ui=4.5, est=3.8320573976250603, details={'was_impossible': False}),
#  Prediction(uid=33259, iid=1258, r_ui=5.0, est=4.019832445059674, details={'was_impossible': False}),
#  Prediction(uid=183445, iid=47629, r_ui=2.0, est=3.3090848592376574, details={'was_impossible': False}),
#  Prediction(uid=89915, iid=724, r_ui=0.5, est=3.322777075582515, details={'was_impossible': False}),
#  Prediction(uid=190452, iid=5445, r_ui=1.5, est=2.555486719104784, details={'was_impossible': False}),
#  Prediction(uid=117906, iid=661, r_ui=4.0, est=3.659755048015754, details={'was_impossible': False}),
#  Prediction(uid=112350, iid=3996, r_ui=0.5, est=3.927630954388481, details={'was_impossible': False}),
#  Prediction(uid=51081, iid=8950, r_ui=4.0, est=3.879777122503914, details={'was_impossible': False}),
#  Prediction(uid=286312, iid=142448, r_ui=3.0, est=3.4180758203819215, details={'was_impossible': False}),
#  Prediction(uid=237619, iid=1260, r_ui=5.0, est=4.127958540753259, details={'was_impossible': False}),
#  Prediction(uid=29068, iid=292, r_ui=2.5, est=3.711844877535328, details={'was_impossible': False}),
#  Prediction(uid=239008, iid=2523, r_ui=3.0, est=3.5016204203780457, details={'was_impossible': False}),
#  Prediction(uid=72387, iid=586, r_ui=3.0, est=2.761861379569477, details={'was_impossible': False}),
#  Prediction(uid=4898, iid=2420, r_ui=1.5, est=3.071704516410738, details={'was_impossible': False}),
#  Prediction(uid=92613, iid=1682, r_ui=4.0, est=3.808988813423588, details={'was_impossible': False}),
#  Prediction(uid=102177, iid=249, r_ui=4.5, est=3.5746737286852053, details={'was_impossible': False}),
#  Prediction(uid=130900, iid=592, r_ui=4.0, est=3.3078487847143916, details={'was_impossible': False}),
#  Prediction(uid=304943, iid=1542, r_ui=3.0, est=3.7876803060651425, details={'was_impossible': False}),
#  Prediction(uid=222265, iid=4973, r_ui=4.5, est=4.022574246274036, details={'was_impossible': False}),
#  Prediction(uid=311965, iid=2470, r_ui=3.5, est=3.276785398081974, details={'was_impossible': False}),
#  Prediction(uid=129288, iid=70, r_ui=4.0, est=3.3807676906820907, details={'was_impossible': False}),
#  Prediction(uid=263950, iid=1304, r_ui=4.0, est=3.938573835028475, details={'was_impossible': False}),
#  Prediction(uid=98705, iid=152081, r_ui=2.0, est=3.789189571209442, details={'was_impossible': False}),
#  Prediction(uid=51718, iid=177615, r_ui=4.0, est=3.491826574902609, details={'was_impossible': False}),
#  Prediction(uid=250931, iid=87306, r_ui=3.0, est=3.269131356284996, details={'was_impossible': False}),
#  Prediction(uid=18804, iid=4027, r_ui=4.0, est=3.8476069512775486, details={'was_impossible': False}),
#  Prediction(uid=20405, iid=65882, r_ui=2.0, est=3.5335727135561177, details={'was_impossible': False}),
#  Prediction(uid=214223, iid=97306, r_ui=5.0, est=3.613696053808607, details={'was_impossible': False}),
#  Prediction(uid=165041, iid=1253, r_ui=4.0, est=3.763154202622344, details={'was_impossible': False}),
#  Prediction(uid=171687, iid=185, r_ui=5.0, est=3.3059991862980422, details={'was_impossible': False}),
#  Prediction(uid=184263, iid=8368, r_ui=5.0, est=3.6754909844874306, details={'was_impossible': False}),
#  Prediction(uid=195810, iid=318, r_ui=5.0, est=4.898937593400787, details={'was_impossible': False}),
#  Prediction(uid=138851, iid=108727, r_ui=3.5, est=3.5623215211386827, details={'was_impossible': False}),
#  Prediction(uid=208001, iid=45517, r_ui=2.0, est=3.3853037575281704, details={'was_impossible': False}),
#  Prediction(uid=212747, iid=7981, r_ui=4.0, est=3.6588642105072022, details={'was_impossible': False}),
#  Prediction(uid=220032, iid=2151, r_ui=4.0, est=3.5550057500541996, details={'was_impossible': False}),
#  Prediction(uid=207602, iid=1218, r_ui=4.0, est=3.7928120567215973, details={'was_impossible': False}),
#  Prediction(uid=312504, iid=173707, r_ui=3.0, est=3.6375339277498306, details={'was_impossible': False}),
#  Prediction(uid=54822, iid=780, r_ui=2.0, est=3.5156600052959472, details={'was_impossible': False}),
#  Prediction(uid=185170, iid=53161, r_ui=4.0, est=3.6626549678575566, details={'was_impossible': False}),
#  Prediction(uid=310337, iid=208289, r_ui=3.5, est=3.54615, details={'was_impossible': False}),
#  Prediction(uid=23082, iid=8873, r_ui=4.0, est=3.78499430458956, details={'was_impossible': False}),
#  Prediction(uid=161123, iid=31410, r_ui=4.0, est=3.9165520869958654, details={'was_impossible': False}),
#  Prediction(uid=309013, iid=5995, r_ui=3.5, est=3.8661775778013476, details={'was_impossible': False}),
#  Prediction(uid=100165, iid=26555, r_ui=1.0, est=3.159144778855373, details={'was_impossible': False}),
#  Prediction(uid=135538, iid=588, r_ui=4.5, est=3.643552617845921, details={'was_impossible': False}),
#  Prediction(uid=287877, iid=135603, r_ui=3.0, est=3.432077614135941, details={'was_impossible': False}),
#  Prediction(uid=54910, iid=596, r_ui=4.0, est=3.264038997023957, details={'was_impossible': False}),
#  Prediction(uid=122184, iid=293, r_ui=3.0, est=3.1803998275199477, details={'was_impossible': False}),
#  Prediction(uid=77199, iid=6537, r_ui=3.0, est=2.9016687615796384, details={'was_impossible': False}),
#  Prediction(uid=190007, iid=3039, r_ui=4.0, est=3.738365842839079, details={'was_impossible': False}),
#  Prediction(uid=207838, iid=3424, r_ui=4.0, est=3.929410076220791, details={'was_impossible': False}),
#  Prediction(uid=204495, iid=191823, r_ui=3.0, est=3.2974063316918203, details={'was_impossible': False}),
#  Prediction(uid=184153, iid=212361, r_ui=3.5, est=3.6205311199131343, details={'was_impossible': False}),
#  Prediction(uid=323248, iid=4886, r_ui=4.0, est=3.756894231948532, details={'was_impossible': False}),
#  Prediction(uid=320101, iid=5952, r_ui=5.0, est=4.020782390296399, details={'was_impossible': False}),
#  Prediction(uid=152857, iid=95237, r_ui=2.0, est=3.3676233229001475, details={'was_impossible': False}),
#  Prediction(uid=126524, iid=106487, r_ui=4.0, est=3.563069710062533, details={'was_impossible': False}),
#  Prediction(uid=323852, iid=3996, r_ui=4.0, est=3.8812908495570513, details={'was_impossible': False}),
#  Prediction(uid=155398, iid=3740, r_ui=4.0, est=3.5015986991673733, details={'was_impossible': False}),
#  Prediction(uid=80078, iid=694, r_ui=3.0, est=3.352051599635813, details={'was_impossible': False}),
#  Prediction(uid=17792, iid=2141, r_ui=3.0, est=3.5429424891518186, details={'was_impossible': False}),
#  Prediction(uid=50515, iid=57669, r_ui=5.0, est=4.248196893119305, details={'was_impossible': False}),
#  Prediction(uid=289152, iid=541, r_ui=4.0, est=4.078861174011186, details={'was_impossible': False}),
#  Prediction(uid=97158, iid=7373, r_ui=3.0, est=3.276540887880467, details={'was_impossible': False}),
#  Prediction(uid=204139, iid=102125, r_ui=3.0, est=3.8482470847888357, details={'was_impossible': False}),
#  Prediction(uid=245987, iid=48774, r_ui=4.5, est=3.724048374470997, details={'was_impossible': False}),
#  Prediction(uid=323256, iid=87232, r_ui=5.0, est=3.678307912660191, details={'was_impossible': False}),
#  Prediction(uid=15912, iid=2076, r_ui=5.0, est=4.093389456300252, details={'was_impossible': False}),
#  Prediction(uid=19361, iid=1101, r_ui=3.0, est=3.2100951213847186, details={'was_impossible': False}),
#  Prediction(uid=310909, iid=527, r_ui=4.0, est=4.229643626372452, details={'was_impossible': False}),
#  Prediction(uid=184775, iid=51884, r_ui=3.0, est=2.9392386293765376, details={'was_impossible': False}),
#  Prediction(uid=4388, iid=2686, r_ui=3.0, est=3.2121407725613103, details={'was_impossible': False}),
#  Prediction(uid=48244, iid=4681, r_ui=4.0, est=3.4116478031877557, details={'was_impossible': False}),
#  Prediction(uid=228591, iid=5463, r_ui=2.5, est=3.1506762116184475, details={'was_impossible': False}),
#  Prediction(uid=315511, iid=2712, r_ui=4.5, est=2.517926156932198, details={'was_impossible': False}),
#  Prediction(uid=15655, iid=2762, r_ui=4.5, est=3.7217277778089644, details={'was_impossible': False}),
#  Prediction(uid=285595, iid=1210, r_ui=4.0, est=3.9581693722734923, details={'was_impossible': False}),
#  Prediction(uid=147187, iid=1597, r_ui=3.5, est=3.3617560341598987, details={'was_impossible': False}),
#  Prediction(uid=312641, iid=216, r_ui=3.0, est=3.392789440717655, details={'was_impossible': False}),
#  Prediction(uid=284037, iid=296, r_ui=4.0, est=4.191082044961874, details={'was_impossible': False}),
#  Prediction(uid=174381, iid=339, r_ui=2.0, est=3.457810107650155, details={'was_impossible': False}),
#  Prediction(uid=271444, iid=17, r_ui=5.0, est=3.750357819542902, details={'was_impossible': False}),
#  Prediction(uid=172696, iid=4275, r_ui=4.0, est=3.1483207706144416, details={'was_impossible': False}),
#  Prediction(uid=26507, iid=1378, r_ui=2.0, est=3.2000450983377093, details={'was_impossible': False}),
#  Prediction(uid=186996, iid=3988, r_ui=1.0, est=2.8709713074095706, details={'was_impossible': False}),
#  Prediction(uid=321369, iid=2858, r_ui=4.0, est=4.183151309222146, details={'was_impossible': False}),
#  Prediction(uid=4718, iid=139644, r_ui=4.5, est=3.39780655261824, details={'was_impossible': False}),
#  Prediction(uid=67757, iid=2959, r_ui=4.0, est=4.252006991519152, details={'was_impossible': False}),
#  Prediction(uid=121793, iid=183699, r_ui=4.0, est=3.5277575576665945, details={'was_impossible': False}),
#  Prediction(uid=289200, iid=8810, r_ui=4.0, est=3.0326354911751046, details={'was_impossible': False}),
#  Prediction(uid=14241, iid=52435, r_ui=5.0, est=3.5133923672382394, details={'was_impossible': False}),
#  Prediction(uid=324894, iid=288, r_ui=1.0, est=3.0927515322587356, details={'was_impossible': False}),
#  Prediction(uid=274115, iid=1591, r_ui=4.0, est=3.0641168296265957, details={'was_impossible': False}),
#  Prediction(uid=76575, iid=8499, r_ui=2.5, est=3.5483309198712667, details={'was_impossible': False}),
#  Prediction(uid=302871, iid=6539, r_ui=5.0, est=3.8547170332895124, details={'was_impossible': False}),
#  Prediction(uid=35136, iid=68237, r_ui=3.0, est=4.211568932941207, details={'was_impossible': False}),
#  Prediction(uid=53960, iid=260, r_ui=4.0, est=3.818375665311857, details={'was_impossible': False}),
#  Prediction(uid=47103, iid=3016, r_ui=3.0, est=3.0668106486807147, details={'was_impossible': False}),
#  Prediction(uid=38845, iid=26052, r_ui=3.5, est=3.584630138110081, details={'was_impossible': False}),
#  Prediction(uid=149071, iid=482, r_ui=3.0, est=3.5592223858084746, details={'was_impossible': False}),
#  Prediction(uid=58551, iid=89904, r_ui=4.0, est=3.3517352174476964, details={'was_impossible': False}),
#  Prediction(uid=202326, iid=4262, r_ui=2.5, est=4.139422921806198, details={'was_impossible': False}),
#  Prediction(uid=152722, iid=1801, r_ui=3.5, est=3.203584664941477, details={'was_impossible': False}),
#  Prediction(uid=270503, iid=3489, r_ui=4.0, est=3.3964780951905693, details={'was_impossible': False}),
#  Prediction(uid=70939, iid=500, r_ui=3.0, est=3.545555302739326, details={'was_impossible': False}),
#  Prediction(uid=280501, iid=1228, r_ui=5.0, est=3.9867683600710424, details={'was_impossible': False}),
#  Prediction(uid=180767, iid=96079, r_ui=5.0, est=3.856679471626189, details={'was_impossible': False}),
#  Prediction(uid=134666, iid=1193, r_ui=4.5, est=4.307972428635457, details={'was_impossible': False}),
#  Prediction(uid=152443, iid=886, r_ui=5.0, est=3.515528030028831, details={'was_impossible': False}),
#  Prediction(uid=24578, iid=8531, r_ui=3.0, est=3.9579379643302044, details={'was_impossible': False}),
#  Prediction(uid=127601, iid=150, r_ui=5.0, est=3.9238551400296275, details={'was_impossible': False}),
#  Prediction(uid=215012, iid=909, r_ui=5.0, est=4.1402609828799575, details={'was_impossible': False}),
#  Prediction(uid=65258, iid=189713, r_ui=3.5, est=3.8602600556467954, details={'was_impossible': False}),
#  Prediction(uid=144868, iid=4262, r_ui=1.0, est=4.055389904584432, details={'was_impossible': False}),
#  Prediction(uid=45512, iid=1237, r_ui=5.0, est=4.002334888551868, details={'was_impossible': False}),
#  Prediction(uid=305500, iid=1263, r_ui=5.0, est=3.7467214931108805, details={'was_impossible': False}),
#  Prediction(uid=55612, iid=51077, r_ui=3.5, est=3.3424459243860487, details={'was_impossible': False}),
#  Prediction(uid=72214, iid=1348, r_ui=5.0, est=3.6785920739297553, details={'was_impossible': False}),
#  Prediction(uid=294542, iid=95167, r_ui=4.5, est=3.7178108941718446, details={'was_impossible': False}),
#  Prediction(uid=316955, iid=91529, r_ui=5.0, est=4.02023130830275, details={'was_impossible': False}),
#  Prediction(uid=231991, iid=349, r_ui=3.0, est=3.68058180249908, details={'was_impossible': False}),
#  Prediction(uid=288846, iid=2699, r_ui=4.0, est=2.868719270030999, details={'was_impossible': False}),
#  Prediction(uid=193518, iid=410, r_ui=1.0, est=3.003756256896619, details={'was_impossible': False}),
#  Prediction(uid=316711, iid=64957, r_ui=4.0, est=3.598917260701922, details={'was_impossible': False}),
#  Prediction(uid=262855, iid=836, r_ui=3.5, est=2.91446259372056, details={'was_impossible': False}),
#  Prediction(uid=327198, iid=2707, r_ui=2.0, est=3.374635909665369, details={'was_impossible': False}),
#  Prediction(uid=225003, iid=6297, r_ui=4.0, est=3.3300868246240465, details={'was_impossible': False}),
#  Prediction(uid=227232, iid=113573, r_ui=2.0, est=3.563495492835212, details={'was_impossible': False}),
#  Prediction(uid=186620, iid=555, r_ui=4.0, est=3.8939668613632983, details={'was_impossible': False}),
#  Prediction(uid=100960, iid=2712, r_ui=4.0, est=3.3652683570552004, details={'was_impossible': False}),
#  Prediction(uid=99716, iid=2081, r_ui=5.0, est=3.5453423398823785, details={'was_impossible': False}),
#  Prediction(uid=154332, iid=1073, r_ui=5.0, est=3.6487200902511194, details={'was_impossible': False}),
#  Prediction(uid=45195, iid=150, r_ui=5.0, est=3.9238551400296275, details={'was_impossible': False}),
#  Prediction(uid=239874, iid=1892, r_ui=4.0, est=3.325104247547032, details={'was_impossible': False}),
#  Prediction(uid=40824, iid=103688, r_ui=0.5, est=3.541819443869262, details={'was_impossible': False}),
#  Prediction(uid=15303, iid=66659, r_ui=4.0, est=3.349774840668316, details={'was_impossible': False}),
#  Prediction(uid=297503, iid=318, r_ui=4.0, est=4.462516639365968, details={'was_impossible': False}),
#  Prediction(uid=285563, iid=45499, r_ui=4.5, est=3.7144989264824533, details={'was_impossible': False}),
#  Prediction(uid=294287, iid=61240, r_ui=4.0, est=3.8601066752385234, details={'was_impossible': False}),
#  Prediction(uid=150929, iid=3702, r_ui=2.5, est=3.4809617236264643, details={'was_impossible': False}),
#  Prediction(uid=59782, iid=1673, r_ui=5.0, est=3.5989649752482276, details={'was_impossible': False}),
#  Prediction(uid=115091, iid=50872, r_ui=5.0, est=3.832243397790823, details={'was_impossible': False}),
#  Prediction(uid=41356, iid=1307, r_ui=3.0, est=3.865187659410518, details={'was_impossible': False}),
#  Prediction(uid=112427, iid=3471, r_ui=3.5, est=3.7865121366044945, details={'was_impossible': False}),
#  Prediction(uid=38024, iid=534, r_ui=5.0, est=3.557466806796766, details={'was_impossible': False}),
#  Prediction(uid=84725, iid=2028, r_ui=4.0, est=3.985134241694334, details={'was_impossible': False}),
#  Prediction(uid=127766, iid=3114, r_ui=1.5, est=3.7213439196790348, details={'was_impossible': False}),
#  Prediction(uid=71035, iid=2915, r_ui=4.0, est=3.6144170298022895, details={'was_impossible': False}),
#  Prediction(uid=242304, iid=4886, r_ui=5.0, est=3.8119916092584583, details={'was_impossible': False}),
#  Prediction(uid=306456, iid=8874, r_ui=4.5, est=3.799059302151443, details={'was_impossible': False}),
#  Prediction(uid=169158, iid=4458, r_ui=3.5, est=3.519031445307457, details={'was_impossible': False}),
#  Prediction(uid=159807, iid=8529, r_ui=1.0, est=3.486680327107713, details={'was_impossible': False}),
#  Prediction(uid=227720, iid=49274, r_ui=2.0, est=3.4678205051530178, details={'was_impossible': False}),
#  Prediction(uid=171803, iid=142184, r_ui=3.5, est=3.2642404957666393, details={'was_impossible': False}),
#  Prediction(uid=220894, iid=46723, r_ui=3.5, est=3.717124626042563, details={'was_impossible': False}),
#  Prediction(uid=203002, iid=7380, r_ui=1.0, est=3.3198951705120816, details={'was_impossible': False}),
#  Prediction(uid=209773, iid=3114, r_ui=4.0, est=3.810937069500173, details={'was_impossible': False}),
#  Prediction(uid=202884, iid=2291, r_ui=3.0, est=3.763794377565489, details={'was_impossible': False}),
#  Prediction(uid=156905, iid=151, r_ui=3.0, est=3.9249911543390104, details={'was_impossible': False}),
#  Prediction(uid=89910, iid=1271, r_ui=4.0, est=3.3955923491538984, details={'was_impossible': False}),
#  Prediction(uid=279538, iid=5010, r_ui=2.0, est=3.723748693489317, details={'was_impossible': False}),
#  Prediction(uid=59249, iid=2116, r_ui=3.0, est=2.9142720369499036, details={'was_impossible': False}),
#  Prediction(uid=264460, iid=1266, r_ui=4.0, est=3.908169357508826, details={'was_impossible': False}),
#  Prediction(uid=91158, iid=2273, r_ui=4.0, est=3.672423695906051, details={'was_impossible': False}),
#  Prediction(uid=31125, iid=5418, r_ui=4.0, est=3.863921413497209, details={'was_impossible': False}),
#  Prediction(uid=214642, iid=5956, r_ui=4.5, est=3.562733885635236, details={'was_impossible': False}),
#  Prediction(uid=28682, iid=3354, r_ui=3.0, est=2.6453042980982664, details={'was_impossible': False}),
#  Prediction(uid=19515, iid=226270, r_ui=4.5, est=3.774809377225561, details={'was_impossible': False}),
#  Prediction(uid=46798, iid=7361, r_ui=4.5, est=4.16500521856012, details={'was_impossible': False}),
#  Prediction(uid=40381, iid=102993, r_ui=3.5, est=3.4371115953303435, details={'was_impossible': False}),
#  Prediction(uid=95659, iid=219994, r_ui=3.5, est=3.583598418034012, details={'was_impossible': False}),
#  Prediction(uid=233346, iid=3745, r_ui=5.0, est=3.4003031305088216, details={'was_impossible': False}),
#  Prediction(uid=139919, iid=2335, r_ui=2.5, est=1.1689250154713793, details={'was_impossible': False}),
#  Prediction(uid=217008, iid=4343, r_ui=0.5, est=2.9459043698122973, details={'was_impossible': False}),
#  Prediction(uid=320460, iid=7360, r_ui=4.0, est=3.5505092477781557, details={'was_impossible': False}),
#  Prediction(uid=164285, iid=31696, r_ui=3.5, est=3.2245171895284477, details={'was_impossible': False}),
#  Prediction(uid=26056, iid=5378, r_ui=4.0, est=3.496735270930808, details={'was_impossible': False}),
#  Prediction(uid=154235, iid=3408, r_ui=5.0, est=3.719863850344535, details={'was_impossible': False}),
#  Prediction(uid=266787, iid=1347, r_ui=5.0, est=3.3769163753466622, details={'was_impossible': False}),
#  Prediction(uid=209198, iid=780, r_ui=1.0, est=3.5156600052959472, details={'was_impossible': False}),
#  Prediction(uid=230443, iid=349, r_ui=4.0, est=3.68058180249908, details={'was_impossible': False}),
#  Prediction(uid=277880, iid=2442, r_ui=4.0, est=3.677210024488916, details={'was_impossible': False}),
#  Prediction(uid=49877, iid=66097, r_ui=0.5, est=3.7181944292650506, details={'was_impossible': False}),
#  Prediction(uid=136957, iid=6655, r_ui=2.0, est=3.54615, details={'was_impossible': False}),
#  Prediction(uid=267827, iid=5159, r_ui=1.5, est=3.529481537439121, details={'was_impossible': False}),
#  Prediction(uid=4682, iid=1370, r_ui=2.0, est=3.5922333722678745, details={'was_impossible': False}),
#  Prediction(uid=293781, iid=4995, r_ui=0.5, est=3.9920390866355775, details={'was_impossible': False}),
#  Prediction(uid=27113, iid=115713, r_ui=5.0, est=3.778314496535524, details={'was_impossible': False}),
#  Prediction(uid=274147, iid=2194, r_ui=4.0, est=3.8744680161826706, details={'was_impossible': False}),
#  Prediction(uid=258667, iid=2145, r_ui=3.0, est=3.930788323447688, details={'was_impossible': False}),
#  Prediction(uid=139003, iid=21, r_ui=3.0, est=3.472746032009505, details={'was_impossible': False}),
#  Prediction(uid=149937, iid=3448, r_ui=3.0, est=3.450655219620888, details={'was_impossible': False}),
#  Prediction(uid=34168, iid=1246, r_ui=4.0, est=4.157042474369899, details={'was_impossible': False}),
#  Prediction(uid=15390, iid=517, r_ui=3.0, est=3.3306982271440395, details={'was_impossible': False}),
#  Prediction(uid=71544, iid=26248, r_ui=4.5, est=3.1128621631558686, details={'was_impossible': False}),
#  Prediction(uid=285270, iid=31658, r_ui=4.5, est=4.139169727404753, details={'was_impossible': False}),
#  Prediction(uid=102088, iid=3551, r_ui=4.0, est=3.72663977550685, details={'was_impossible': False}),
#  Prediction(uid=300118, iid=1130, r_ui=3.0, est=3.3634715724477324, details={'was_impossible': False}),
#  Prediction(uid=302785, iid=4187, r_ui=3.5, est=3.5941528046387874, details={'was_impossible': False}),
#  Prediction(uid=281484, iid=33004, r_ui=3.5, est=3.558268195977123, details={'was_impossible': False}),
#  Prediction(uid=110738, iid=46723, r_ui=3.5, est=3.9757579269873493, details={'was_impossible': False}),
#  Prediction(uid=225065, iid=1, r_ui=5.0, est=3.993427942947236, details={'was_impossible': False}),
#  Prediction(uid=68635, iid=106489, r_ui=3.5, est=3.672812036683132, details={'was_impossible': False}),
#  Prediction(uid=307411, iid=91658, r_ui=3.5, est=3.3186613997729606, details={'was_impossible': False}),
#  Prediction(uid=168609, iid=103141, r_ui=4.0, est=3.5926256269273926, details={'was_impossible': False}),
#  Prediction(uid=295906, iid=1721, r_ui=5.0, est=3.5192754331446805, details={'was_impossible': False}),
#  Prediction(uid=122066, iid=48774, r_ui=3.0, est=3.724048374470997, details={'was_impossible': False}),
#  Prediction(uid=50007, iid=6297, r_ui=4.0, est=3.3300868246240465, details={'was_impossible': False}),
#  Prediction(uid=300689, iid=141, r_ui=3.0, est=3.6157433439722393, details={'was_impossible': False}),
#  Prediction(uid=114523, iid=210569, r_ui=4.5, est=3.3321091764437645, details={'was_impossible': False}),
#  Prediction(uid=153297, iid=6400, r_ui=3.5, est=3.455246064275303, details={'was_impossible': False}),
#  Prediction(uid=65740, iid=1883, r_ui=4.0, est=3.436459105829932, details={'was_impossible': False}),
#  Prediction(uid=180878, iid=222593, r_ui=2.5, est=2.7694897658941002, details={'was_impossible': False}),
#  Prediction(uid=45649, iid=48872, r_ui=4.0, est=3.2471449638572385, details={'was_impossible': False}),
#  Prediction(uid=193237, iid=94266, r_ui=3.5, est=3.660818684063684, details={'was_impossible': False}),
#  Prediction(uid=125864, iid=53883, r_ui=4.0, est=3.499905215087657, details={'was_impossible': False}),
#  Prediction(uid=79505, iid=4767, r_ui=2.5, est=3.518624038827156, details={'was_impossible': False}),
#  Prediction(uid=182826, iid=109374, r_ui=4.0, est=3.9432583584085954, details={'was_impossible': False}),
#  Prediction(uid=105540, iid=349, r_ui=5.0, est=3.5360922841199187, details={'was_impossible': False}),
#  Prediction(uid=91096, iid=1257, r_ui=4.0, est=3.7477512810543137, details={'was_impossible': False}),
#  Prediction(uid=85904, iid=4975, r_ui=4.0, est=3.5881477293141675, details={'was_impossible': False}),
#  Prediction(uid=138812, iid=8493, r_ui=4.0, est=3.594285081768723, details={'was_impossible': False}),
#  Prediction(uid=242363, iid=393, r_ui=2.0, est=2.286734317623987, details={'was_impossible': False}),
#  Prediction(uid=125518, iid=4887, r_ui=3.0, est=2.9465184506113538, details={'was_impossible': False}),
#  Prediction(uid=281151, iid=2297, r_ui=4.5, est=3.233908885602183, details={'was_impossible': False}),
#  Prediction(uid=295666, iid=40723, r_ui=3.0, est=3.513437878264843, details={'was_impossible': False}),
#  Prediction(uid=210101, iid=1682, r_ui=4.0, est=3.616269079279877, details={'was_impossible': False}),
#  Prediction(uid=74145, iid=110, r_ui=4.5, est=3.993000672463968, details={'was_impossible': False}),
#  Prediction(uid=85461, iid=1876, r_ui=3.5, est=3.1264976587461613, details={'was_impossible': False}),
#  Prediction(uid=308274, iid=1625, r_ui=4.0, est=3.999742392303365, details={'was_impossible': False}),
#  Prediction(uid=146731, iid=60069, r_ui=5.0, est=4.017591572531207, details={'was_impossible': False}),
#  Prediction(uid=23539, iid=318, r_ui=5.0, est=4.462516639365968, details={'was_impossible': False}),
#  Prediction(uid=92373, iid=923, r_ui=4.0, est=4.080403030076157, details={'was_impossible': False}),
#  Prediction(uid=13759, iid=76251, r_ui=4.0, est=3.5700506817787856, details={'was_impossible': False}),
#  Prediction(uid=115095, iid=1198, r_ui=4.0, est=4.007939150223952, details={'was_impossible': False}),
#  Prediction(uid=243649, iid=3079, r_ui=3.0, est=3.8249765438557337, details={'was_impossible': False}),
#  Prediction(uid=321017, iid=3977, r_ui=1.0, est=2.8195486069521736, details={'was_impossible': False}),
#  Prediction(uid=305333, iid=83270, r_ui=4.0, est=3.54615, details={'was_impossible': False}),
#  Prediction(uid=217173, iid=2335, r_ui=2.0, est=2.8864711388736484, details={'was_impossible': False}),
#  Prediction(uid=302206, iid=910, r_ui=4.5, est=3.86813719298088, details={'was_impossible': False}),
#  Prediction(uid=279650, iid=87306, r_ui=3.0, est=3.4444039459090448, details={'was_impossible': False}),
#  Prediction(uid=309999, iid=8126, r_ui=3.0, est=3.618807729886825, details={'was_impossible': False}),
#  Prediction(uid=24845, iid=5180, r_ui=3.0, est=3.617984588454089, details={'was_impossible': False}),
#  Prediction(uid=45584, iid=72378, r_ui=2.0, est=2.913366115490931, details={'was_impossible': False}),
#  Prediction(uid=308450, iid=7444, r_ui=1.5, est=3.5435739385637914, details={'was_impossible': False}),
#  Prediction(uid=389, iid=2780, r_ui=2.0, est=3.428070456894373, details={'was_impossible': False}),
#  Prediction(uid=100749, iid=1225, r_ui=4.0, est=4.099689617154212, details={'was_impossible': False}),
#  Prediction(uid=52199, iid=122882, r_ui=1.5, est=3.7190662724610286, details={'was_impossible': False}),
#  Prediction(uid=226192, iid=3114, r_ui=4.0, est=3.8275888446685316, details={'was_impossible': False}),
#  Prediction(uid=178558, iid=135569, r_ui=4.0, est=3.774781923159118, details={'was_impossible': False}),
#  Prediction(uid=23836, iid=318, r_ui=5.0, est=4.462516639365968, details={'was_impossible': False}),
#  Prediction(uid=238585, iid=134130, r_ui=3.5, est=3.9017617387395935, details={'was_impossible': False}),
#  Prediction(uid=16466, iid=136345, r_ui=1.5, est=3.54615, details={'was_impossible': False}),
#  Prediction(uid=229138, iid=4979, r_ui=3.5, est=3.7336885754885074, details={'was_impossible': False}),
#  Prediction(uid=238068, iid=6419, r_ui=5.0, est=3.6750443018705505, details={'was_impossible': False}),
#  Prediction(uid=260482, iid=218537, r_ui=3.5, est=3.770846618224494, details={'was_impossible': False}),
#  Prediction(uid=296119, iid=1918, r_ui=2.5, est=3.3075293899912306, details={'was_impossible': False}),
#  Prediction(uid=292172, iid=81845, r_ui=5.0, est=3.9240502475167705, details={'was_impossible': False}),
#  Prediction(uid=39750, iid=95441, r_ui=2.5, est=3.110308001648533, details={'was_impossible': False}),
#  Prediction(uid=268315, iid=190555, r_ui=4.0, est=3.560993340413287, details={'was_impossible': False}),
#  Prediction(uid=235184, iid=49272, r_ui=3.5, est=3.908561949705509, details={'was_impossible': False}),
#  Prediction(uid=114822, iid=6468, r_ui=3.0, est=3.54615, details={'was_impossible': False}),
#  Prediction(uid=17722, iid=6942, r_ui=4.0, est=3.6949525520008133, details={'was_impossible': False}),
#  Prediction(uid=231126, iid=2712, r_ui=1.0, est=3.318588094132002, details={'was_impossible': False}),
#  Prediction(uid=26208, iid=122916, r_ui=5.0, est=3.9597188723896677, details={'was_impossible': False}),
#  Prediction(uid=187533, iid=527, r_ui=3.5, est=4.268635707468755, details={'was_impossible': False}),
#  Prediction(uid=150681, iid=748, r_ui=3.0, est=3.2534786120956087, details={'was_impossible': False}),
#  Prediction(uid=225667, iid=47, r_ui=3.0, est=4.016948736298766, details={'was_impossible': False}),
#  Prediction(uid=152999, iid=4226, r_ui=5.0, est=4.025215357717653, details={'was_impossible': False}),
#  Prediction(uid=316659, iid=1201, r_ui=4.0, est=4.306492110133652, details={'was_impossible': False}),
#  Prediction(uid=44664, iid=527, r_ui=5.0, est=4.268635707468755, details={'was_impossible': False}),
#  Prediction(uid=115607, iid=553, r_ui=5.0, est=3.805803637446668, details={'was_impossible': False}),
#  Prediction(uid=159722, iid=1073, r_ui=3.0, est=3.808376688395176, details={'was_impossible': False}),
#  Prediction(uid=18312, iid=175303, r_ui=4.0, est=3.322712744129882, details={'was_impossible': False}),
#  Prediction(uid=165597, iid=277, r_ui=5.0, est=3.3371059766787643, details={'was_impossible': False}),
#  Prediction(uid=166758, iid=2011, r_ui=4.0, est=3.68535443305649, details={'was_impossible': False}),
#  Prediction(uid=3892, iid=27808, r_ui=4.0, est=3.3216885085827097, details={'was_impossible': False}),
#  Prediction(uid=271843, iid=36, r_ui=1.5, est=3.9677830789441026, details={'was_impossible': False}),
#  Prediction(uid=226413, iid=3786, r_ui=3.0, est=3.0621021521649117, details={'was_impossible': False}),
#  Prediction(uid=270627, iid=7319, r_ui=0.5, est=3.2219990431687235, details={'was_impossible': False}),
#  Prediction(uid=311382, iid=4262, r_ui=5.0, est=4.097500181999826, details={'was_impossible': False}),
#  Prediction(uid=231001, iid=2707, r_ui=3.5, est=3.374635909665369, details={'was_impossible': False}),
#  Prediction(uid=260474, iid=6615, r_ui=3.0, est=2.5119529435051304, details={'was_impossible': False}),
#  Prediction(uid=301724, iid=235, r_ui=2.0, est=3.741354351446257, details={'was_impossible': False}),
#  Prediction(uid=81416, iid=4994, r_ui=2.5, est=3.557254329432354, details={'was_impossible': False}),
#  Prediction(uid=3607, iid=3252, r_ui=4.0, est=3.9470222526832366, details={'was_impossible': False}),
#  Prediction(uid=144190, iid=27878, r_ui=3.5, est=3.5750553354802976, details={'was_impossible': False}),
#  Prediction(uid=264495, iid=48394, r_ui=4.0, est=3.633149205517021, details={'was_impossible': False}),
#  Prediction(uid=279109, iid=4034, r_ui=5.0, est=3.8004875177515256, details={'was_impossible': False}),
#  Prediction(uid=268175, iid=586, r_ui=4.5, est=3.1120000903903198, details={'was_impossible': False}),
#  Prediction(uid=111888, iid=186, r_ui=2.0, est=2.714943768345322, details={'was_impossible': False}),
#  Prediction(uid=102490, iid=5220, r_ui=3.0, est=3.5068886938001502, details={'was_impossible': False}),
#  Prediction(uid=136661, iid=40815, r_ui=4.0, est=3.8118032123364225, details={'was_impossible': False}),
#  Prediction(uid=207650, iid=6942, r_ui=3.5, est=3.808851793960361, details={'was_impossible': False}),
#  Prediction(uid=152888, iid=69278, r_ui=2.5, est=3.0520804604185545, details={'was_impossible': False}),
#  Prediction(uid=177143, iid=31427, r_ui=3.5, est=3.2542743481248637, details={'was_impossible': False}),
#  Prediction(uid=45785, iid=1702, r_ui=2.5, est=2.923093677273534, details={'was_impossible': False}),
#  Prediction(uid=247936, iid=4979, r_ui=3.5, est=3.863216613133284, details={'was_impossible': False}),
#  Prediction(uid=38733, iid=653, r_ui=5.0, est=3.1753015779069895, details={'was_impossible': False}),
#  Prediction(uid=56793, iid=1499, r_ui=2.0, est=2.7264691951510143, details={'was_impossible': False}),
#  Prediction(uid=94862, iid=2034, r_ui=4.0, est=3.280334600728419, details={'was_impossible': False}),
#  Prediction(uid=207257, iid=1059, r_ui=3.0, est=3.360764758701494, details={'was_impossible': False}),
#  Prediction(uid=138831, iid=20, r_ui=3.0, est=3.2136014255434633, details={'was_impossible': False}),
#  Prediction(uid=222645, iid=157699, r_ui=5.0, est=3.39270646979948, details={'was_impossible': False}),
#  Prediction(uid=219952, iid=33493, r_ui=4.0, est=3.334963624491163, details={'was_impossible': False}),
#  Prediction(uid=235932, iid=41997, r_ui=0.5, est=3.7684691126944836, details={'was_impossible': False}),
#  Prediction(uid=326484, iid=640, r_ui=4.0, est=3.28699576609099, details={'was_impossible': False}),
#  Prediction(uid=141805, iid=550, r_ui=4.0, est=3.3169304662116192, details={'was_impossible': False}),
#  Prediction(uid=81089, iid=80374, r_ui=4.0, est=3.7032989848395426, details={'was_impossible': False}),
#  Prediction(uid=183080, iid=1193, r_ui=4.0, est=4.307972428635457, details={'was_impossible': False}),
#  Prediction(uid=192796, iid=898, r_ui=4.0, est=3.940161561401097, details={'was_impossible': False}),
#  Prediction(uid=170439, iid=6296, r_ui=3.5, est=3.2799619746398774, details={'was_impossible': False}),
#  Prediction(uid=95298, iid=4062, r_ui=5.0, est=3.448581538574144, details={'was_impossible': False}),
#  Prediction(uid=113522, iid=322, r_ui=3.0, est=3.4666872429446194, details={'was_impossible': False}),
#  Prediction(uid=189614, iid=90071, r_ui=3.5, est=3.135173418002932, details={'was_impossible': False}),
#  Prediction(uid=229109, iid=5337, r_ui=2.0, est=3.5472459307401225, details={'was_impossible': False}),
#  Prediction(uid=264998, iid=919, r_ui=2.0, est=3.7494385526471623, details={'was_impossible': False}),
#  Prediction(uid=316496, iid=91658, r_ui=4.0, est=3.645576752962345, details={'was_impossible': False}),
#  Prediction(uid=22537, iid=54995, r_ui=2.0, est=3.670159624072627, details={'was_impossible': False}),
#  Prediction(uid=174006, iid=2431, r_ui=3.5, est=3.3072354056670017, details={'was_impossible': False}),
#  Prediction(uid=64864, iid=8798, r_ui=4.0, est=3.755062500982496, details={'was_impossible': False}),
#  Prediction(uid=215885, iid=1213, r_ui=4.5, est=4.099466843200438, details={'was_impossible': False}),
#  Prediction(uid=154768, iid=55290, r_ui=4.0, est=3.4419877708064748, details={'was_impossible': False}),
#  Prediction(uid=317407, iid=205441, r_ui=4.0, est=3.4624853558878943, details={'was_impossible': False}),
#  Prediction(uid=134945, iid=79592, r_ui=3.0, est=3.6258516062009227, details={'was_impossible': False}),
#  Prediction(uid=4028, iid=4027, r_ui=4.5, est=3.8476069512775486, details={'was_impossible': False}),
#  Prediction(uid=30216, iid=1479, r_ui=4.0, est=3.3229400827750784, details={'was_impossible': False}),
#  Prediction(uid=17654, iid=1393, r_ui=4.0, est=3.6580446451665263, details={'was_impossible': False}),
#  Prediction(uid=155015, iid=5644, r_ui=4.5, est=3.534355719480192, details={'was_impossible': False}),
#  Prediction(uid=61939, iid=48780, r_ui=5.0, est=4.17233452725425, details={'was_impossible': False}),
#  Prediction(uid=277612, iid=1210, r_ui=3.0, est=3.9581693722734923, details={'was_impossible': False}),
#  Prediction(uid=39902, iid=4886, r_ui=4.0, est=3.6608897298262426, details={'was_impossible': False}),
#  Prediction(uid=97285, iid=1221, r_ui=5.0, est=4.16773230625368, details={'was_impossible': False}),
#  Prediction(uid=268792, iid=6, r_ui=2.5, est=3.7407167570824247, details={'was_impossible': False}),
#  Prediction(uid=209108, iid=1254, r_ui=4.0, est=3.434016283992769, details={'was_impossible': False}),
#  Prediction(uid=1491, iid=97172, r_ui=1.5, est=3.691493081660989, details={'was_impossible': False}),
#  Prediction(uid=3017, iid=946, r_ui=4.0, est=3.4426776844303153, details={'was_impossible': False}),
#  Prediction(uid=96312, iid=91529, r_ui=5.0, est=4.02023130830275, details={'was_impossible': False}),
#  Prediction(uid=133400, iid=3174, r_ui=3.0, est=3.1120424233584925, details={'was_impossible': False}),
#  Prediction(uid=283388, iid=3072, r_ui=5.0, est=3.845631575528002, details={'was_impossible': False}),
# ...
#  Prediction(uid=134204, iid=51662, r_ui=3.5, est=3.7922323372175537, details={'was_impossible': False}),
#  Prediction(uid=63492, iid=5459, r_ui=4.0, est=3.081034518919388, details={'was_impossible': False}),
#  Prediction(uid=52199, iid=171763, r_ui=2.0, est=3.6582278445724534, details={'was_impossible': False}),
#  Prediction(uid=9374, iid=5891, r_ui=3.5, est=3.7536979649265794, details={'was_impossible': False}),
#  Prediction(uid=257021, iid=473, r_ui=3.0, est=3.2510739261432753, details={'was_impossible': False}),
#  Prediction(uid=282137, iid=3424, r_ui=3.5, est=3.886235549515518, details={'was_impossible': False}),
#  Prediction(uid=266292, iid=2003, r_ui=3.0, est=3.0543748711160568, details={'was_impossible': False}),
#  Prediction(uid=256414, iid=2804, r_ui=3.0, est=3.7731815756545832, details={'was_impossible': False}),
#  Prediction(uid=14639, iid=2357, r_ui=5.0, est=3.725285644459247, details={'was_impossible': False}),
#  Prediction(uid=323084, iid=1196, r_ui=5.0, est=3.9489693421772945, details={'was_impossible': False}),
#  Prediction(uid=260102, iid=42, r_ui=3.0, est=3.3854020466535357, details={'was_impossible': False}),
#  Prediction(uid=116494, iid=1911, r_ui=3.5, est=3.0878195250570686, details={'was_impossible': False}),
#  Prediction(uid=74787, iid=586, r_ui=4.5, est=3.1120000903903198, details={'was_impossible': False}),
#  Prediction(uid=22270, iid=81847, r_ui=4.0, est=3.6799271708377472, details={'was_impossible': False}),
#  Prediction(uid=115763, iid=2539, r_ui=4.0, est=3.36812826895549, details={'was_impossible': False}),
#  Prediction(uid=41150, iid=1544, r_ui=4.0, est=3.193349720629775, details={'was_impossible': False}),
#  Prediction(uid=49782, iid=2193, r_ui=4.0, est=3.638160914482533, details={'was_impossible': False}),
#  Prediction(uid=248116, iid=7280, r_ui=3.5, est=3.2975166361192496, details={'was_impossible': False}),
#  Prediction(uid=102689, iid=102445, r_ui=5.0, est=3.729263933141033, details={'was_impossible': False}),
#  Prediction(uid=286227, iid=4993, r_ui=2.0, est=4.056796068649269, details={'was_impossible': False}),
#  Prediction(uid=143142, iid=920, r_ui=3.5, est=3.7677927438854675, details={'was_impossible': False}),
#  Prediction(uid=125264, iid=253, r_ui=4.0, est=3.494927218759076, details={'was_impossible': False}),
#  Prediction(uid=271922, iid=2580, r_ui=4.0, est=3.8190502684265333, details={'was_impossible': False}),
#  Prediction(uid=23268, iid=2692, r_ui=4.5, est=3.928434564314003, details={'was_impossible': False}),
#  Prediction(uid=115180, iid=2028, r_ui=3.0, est=3.995485745569641, details={'was_impossible': False}),
#  Prediction(uid=49959, iid=7367, r_ui=3.5, est=3.2479625733551996, details={'was_impossible': False}),
#  Prediction(uid=283630, iid=736, r_ui=2.5, est=2.7731679745529676, details={'was_impossible': False}),
#  Prediction(uid=131645, iid=1485, r_ui=1.5, est=2.7908695342192225, details={'was_impossible': False}),
#  Prediction(uid=299380, iid=2908, r_ui=1.0, est=3.287709641841661, details={'was_impossible': False}),
#  Prediction(uid=219309, iid=103867, r_ui=4.5, est=3.54615, details={'was_impossible': False}),
#  Prediction(uid=185785, iid=249, r_ui=2.5, est=3.2067287710611554, details={'was_impossible': False}),
#  Prediction(uid=92114, iid=2991, r_ui=5.0, est=2.987748303925702, details={'was_impossible': False}),
#  Prediction(uid=192627, iid=134130, r_ui=3.5, est=4.058913061959415, details={'was_impossible': False}),
#  Prediction(uid=17087, iid=43, r_ui=2.0, est=3.3090958319843797, details={'was_impossible': False}),
#  Prediction(uid=170758, iid=6365, r_ui=3.0, est=3.386850424862702, details={'was_impossible': False}),
#  Prediction(uid=14169, iid=708, r_ui=5.0, est=3.5731064067921925, details={'was_impossible': False}),
#  Prediction(uid=67927, iid=3740, r_ui=2.0, est=3.616879322841339, details={'was_impossible': False}),
#  Prediction(uid=69129, iid=1909, r_ui=4.0, est=3.525538153114017, details={'was_impossible': False}),
#  Prediction(uid=43866, iid=114554, r_ui=5.0, est=3.567155241238773, details={'was_impossible': False}),
#  Prediction(uid=132224, iid=371, r_ui=4.0, est=3.418558171786724, details={'was_impossible': False}),
#  Prediction(uid=127340, iid=1527, r_ui=3.0, est=4.018299251325385, details={'was_impossible': False}),
#  Prediction(uid=42899, iid=111781, r_ui=4.0, est=3.5111357526297837, details={'was_impossible': False}),
#  Prediction(uid=280493, iid=3210, r_ui=4.0, est=3.592758511340676, details={'was_impossible': False}),
#  Prediction(uid=202747, iid=112183, r_ui=4.0, est=3.9870871850128067, details={'was_impossible': False}),
#  Prediction(uid=322280, iid=74, r_ui=4.0, est=3.7641271507476697, details={'was_impossible': False}),
#  Prediction(uid=307022, iid=316, r_ui=4.0, est=3.3539408966855353, details={'was_impossible': False}),
#  Prediction(uid=171780, iid=3628, r_ui=4.5, est=3.54704369420295, details={'was_impossible': False}),
#  Prediction(uid=167279, iid=3255, r_ui=3.5, est=3.728296571506242, details={'was_impossible': False}),
#  Prediction(uid=160553, iid=95, r_ui=3.0, est=3.337761782770908, details={'was_impossible': False}),
#  Prediction(uid=229109, iid=4235, r_ui=5.0, est=3.6459369993618522, details={'was_impossible': False}),
#  Prediction(uid=17431, iid=111, r_ui=3.5, est=4.177595917318828, details={'was_impossible': False}),
#  Prediction(uid=83332, iid=193, r_ui=1.0, est=2.4742540672271485, details={'was_impossible': False}),
#  Prediction(uid=129170, iid=1186, r_ui=4.0, est=3.7576693691288567, details={'was_impossible': False}),
#  Prediction(uid=78708, iid=2081, r_ui=3.0, est=3.507408294937803, details={'was_impossible': False}),
#  Prediction(uid=114971, iid=6539, r_ui=4.5, est=3.8402794030637937, details={'was_impossible': False}),
#  Prediction(uid=242387, iid=2379, r_ui=2.0, est=2.9505138143697396, details={'was_impossible': False}),
#  Prediction(uid=186504, iid=105468, r_ui=2.5, est=3.5040055938639205, details={'was_impossible': False}),
#  Prediction(uid=30402, iid=2329, r_ui=4.5, est=4.106665755369014, details={'was_impossible': False}),
#  Prediction(uid=47082, iid=36, r_ui=5.0, est=3.912733567064873, details={'was_impossible': False}),
#  Prediction(uid=34599, iid=62203, r_ui=2.5, est=3.54615, details={'was_impossible': False}),
#  Prediction(uid=292087, iid=27800, r_ui=4.0, est=3.4848670182014905, details={'was_impossible': False}),
#  Prediction(uid=224216, iid=95510, r_ui=3.0, est=3.401581854687838, details={'was_impossible': False}),
#  Prediction(uid=62368, iid=172, r_ui=3.0, est=3.044473012547372, details={'was_impossible': False}),
#  Prediction(uid=93473, iid=5463, r_ui=4.0, est=3.0084516586081635, details={'was_impossible': False}),
#  Prediction(uid=200203, iid=2770, r_ui=2.0, est=3.177458106751582, details={'was_impossible': False}),
#  Prediction(uid=82020, iid=1395, r_ui=4.0, est=3.5455268246844893, details={'was_impossible': False}),
#  Prediction(uid=58086, iid=8970, r_ui=1.5, est=3.652747632646011, details={'was_impossible': False}),
#  Prediction(uid=79550, iid=151, r_ui=5.0, est=3.7659677772116984, details={'was_impossible': False}),
#  Prediction(uid=61459, iid=3524, r_ui=2.0, est=3.2990348688724755, details={'was_impossible': False}),
#  Prediction(uid=330283, iid=44195, r_ui=4.0, est=3.842865888779405, details={'was_impossible': False}),
#  Prediction(uid=198283, iid=2795, r_ui=3.0, est=3.893582550813436, details={'was_impossible': False}),
#  Prediction(uid=192464, iid=5015, r_ui=0.5, est=3.9062593478632195, details={'was_impossible': False}),
#  Prediction(uid=308007, iid=2046, r_ui=3.0, est=3.553037763627294, details={'was_impossible': False}),
#  Prediction(uid=206055, iid=216338, r_ui=5.0, est=3.7194731682980797, details={'was_impossible': False}),
#  Prediction(uid=224781, iid=327, r_ui=3.0, est=3.3314143356908574, details={'was_impossible': False}),
#  Prediction(uid=304171, iid=589, r_ui=4.0, est=3.880238546343432, details={'was_impossible': False}),
#  Prediction(uid=213004, iid=3185, r_ui=3.5, est=3.3951608861169955, details={'was_impossible': False}),
#  Prediction(uid=165743, iid=50, r_ui=4.0, est=3.959456140309434, details={'was_impossible': False}),
#  Prediction(uid=266840, iid=541, r_ui=5.0, est=4.205832112769469, details={'was_impossible': False}),
#  Prediction(uid=197990, iid=69481, r_ui=4.0, est=3.66872148679264, details={'was_impossible': False}),
#  Prediction(uid=36103, iid=114847, r_ui=2.5, est=3.014587952596988, details={'was_impossible': False}),
#  Prediction(uid=293488, iid=412, r_ui=3.0, est=3.685920340311151, details={'was_impossible': False}),
#  Prediction(uid=85520, iid=2840, r_ui=2.0, est=3.4406867300978905, details={'was_impossible': False}),
#  Prediction(uid=282086, iid=91529, r_ui=3.5, est=3.7716041372387696, details={'was_impossible': False}),
#  Prediction(uid=276602, iid=4623, r_ui=3.5, est=3.519121239017981, details={'was_impossible': False}),
#  Prediction(uid=314092, iid=588, r_ui=4.5, est=3.67490217087914, details={'was_impossible': False}),
#  Prediction(uid=183354, iid=296, r_ui=5.0, est=4.191082044961874, details={'was_impossible': False}),
#  Prediction(uid=241700, iid=1266, r_ui=5.0, est=3.8660189429413268, details={'was_impossible': False}),
#  Prediction(uid=203781, iid=113071, r_ui=3.0, est=3.3635602852048523, details={'was_impossible': False}),
#  Prediction(uid=317440, iid=1090, r_ui=4.0, est=3.7816973884833365, details={'was_impossible': False}),
#  Prediction(uid=124726, iid=33493, r_ui=3.5, est=3.8041200444966394, details={'was_impossible': False}),
#  Prediction(uid=275598, iid=36, r_ui=4.0, est=4.002966259677261, details={'was_impossible': False}),
#  Prediction(uid=298565, iid=56367, r_ui=4.0, est=3.7143336053469485, details={'was_impossible': False}),
#  Prediction(uid=34513, iid=1203, r_ui=4.5, est=4.3059682719182115, details={'was_impossible': False}),
#  Prediction(uid=195038, iid=39, r_ui=4.0, est=3.3922600214697547, details={'was_impossible': False}),
#  Prediction(uid=300312, iid=69844, r_ui=5.0, est=3.9200222560908666, details={'was_impossible': False}),
#  Prediction(uid=270215, iid=184399, r_ui=3.5, est=3.703187965141724, details={'was_impossible': False}),
#  Prediction(uid=210197, iid=376, r_ui=3.5, est=3.2714127853915618, details={'was_impossible': False}),
#  Prediction(uid=137618, iid=51255, r_ui=4.0, est=3.8026308112325204, details={'was_impossible': False}),
#  Prediction(uid=211151, iid=27788, r_ui=5.0, est=3.5165644404534517, details={'was_impossible': False}),
#  Prediction(uid=27222, iid=115149, r_ui=2.5, est=3.8015559961091374, details={'was_impossible': False}),
#  Prediction(uid=136936, iid=256, r_ui=3.0, est=2.8931723294779665, details={'was_impossible': False}),
#  Prediction(uid=58775, iid=378, r_ui=3.0, est=3.484708427942592, details={'was_impossible': False}),
#  Prediction(uid=287411, iid=252, r_ui=3.0, est=3.35696969784643, details={'was_impossible': False}),
#  Prediction(uid=77995, iid=5992, r_ui=2.5, est=3.975675053287003, details={'was_impossible': False}),
#  Prediction(uid=2471, iid=3698, r_ui=2.0, est=3.3951254620168028, details={'was_impossible': False}),
#  Prediction(uid=207798, iid=736, r_ui=3.0, est=3.1169179935228426, details={'was_impossible': False}),
#  Prediction(uid=115503, iid=318, r_ui=5.0, est=4.59166148601745, details={'was_impossible': False}),
#  Prediction(uid=195299, iid=95510, r_ui=3.0, est=3.023452366120766, details={'was_impossible': False}),
#  Prediction(uid=41254, iid=39446, r_ui=3.5, est=3.5164275769521045, details={'was_impossible': False}),
#  Prediction(uid=180795, iid=50068, r_ui=4.0, est=3.6708059064255667, details={'was_impossible': False}),
#  Prediction(uid=278084, iid=47, r_ui=4.0, est=4.016948736298766, details={'was_impossible': False}),
#  Prediction(uid=274514, iid=45722, r_ui=3.0, est=3.613312589307008, details={'was_impossible': False}),
#  Prediction(uid=293889, iid=5013, r_ui=4.5, est=3.7073514756972776, details={'was_impossible': False}),
#  Prediction(uid=128913, iid=3022, r_ui=5.0, est=3.892472021135765, details={'was_impossible': False}),
#  Prediction(uid=149577, iid=48304, r_ui=3.5, est=3.493730713459971, details={'was_impossible': False}),
#  Prediction(uid=277012, iid=1101, r_ui=4.0, est=3.6411355527861926, details={'was_impossible': False}),
#  Prediction(uid=31572, iid=3082, r_ui=3.5, est=3.331662755030365, details={'was_impossible': False}),
#  Prediction(uid=52588, iid=471, r_ui=4.0, est=3.439602975876155, details={'was_impossible': False}),
#  Prediction(uid=5471, iid=364, r_ui=4.0, est=3.6135109787590904, details={'was_impossible': False}),
#  Prediction(uid=63113, iid=82461, r_ui=2.5, est=3.187806622022668, details={'was_impossible': False}),
#  Prediction(uid=102147, iid=592, r_ui=3.5, est=3.3393824028953305, details={'was_impossible': False}),
#  Prediction(uid=113021, iid=7001, r_ui=3.0, est=3.515555868178734, details={'was_impossible': False}),
#  Prediction(uid=329954, iid=95441, r_ui=3.0, est=2.9862969396093377, details={'was_impossible': False}),
#  Prediction(uid=161001, iid=205054, r_ui=3.5, est=3.5480849126703147, details={'was_impossible': False}),
#  Prediction(uid=167235, iid=61160, r_ui=1.0, est=2.983227784606304, details={'was_impossible': False}),
#  Prediction(uid=72254, iid=1359, r_ui=2.5, est=3.1797082465438806, details={'was_impossible': False}),
#  Prediction(uid=162710, iid=1594, r_ui=5.0, est=3.5792610886316836, details={'was_impossible': False}),
#  Prediction(uid=118217, iid=118696, r_ui=2.5, est=3.4953680664040037, details={'was_impossible': False}),
#  Prediction(uid=307528, iid=76077, r_ui=4.0, est=3.388480754635177, details={'was_impossible': False}),
#  Prediction(uid=77864, iid=60072, r_ui=4.5, est=3.3671869080459365, details={'was_impossible': False}),
#  Prediction(uid=223549, iid=72226, r_ui=4.0, est=4.041492998579449, details={'was_impossible': False}),
#  Prediction(uid=301870, iid=25905, r_ui=3.5, est=3.3942396433714705, details={'was_impossible': False}),
#  Prediction(uid=202069, iid=5445, r_ui=4.0, est=3.7012954897261996, details={'was_impossible': False}),
#  Prediction(uid=142955, iid=111384, r_ui=3.5, est=3.4908047085005376, details={'was_impossible': False}),
#  Prediction(uid=243858, iid=1151, r_ui=1.0, est=3.682226142129716, details={'was_impossible': False}),
#  Prediction(uid=318818, iid=1617, r_ui=3.0, est=4.067959459686497, details={'was_impossible': False}),
#  Prediction(uid=149460, iid=2643, r_ui=2.5, est=2.288201930810015, details={'was_impossible': False}),
#  Prediction(uid=134797, iid=282453, r_ui=5.0, est=3.562741287159035, details={'was_impossible': False}),
#  Prediction(uid=261360, iid=314, r_ui=2.0, est=3.908151741050183, details={'was_impossible': False}),
#  Prediction(uid=162400, iid=3362, r_ui=2.0, est=3.7977371325802562, details={'was_impossible': False}),
#  Prediction(uid=168902, iid=88140, r_ui=4.0, est=3.5405652913646763, details={'was_impossible': False}),
#  Prediction(uid=38764, iid=171275, r_ui=0.5, est=3.5274845943559887, details={'was_impossible': False}),
#  Prediction(uid=218671, iid=4744, r_ui=2.5, est=3.3576389755906404, details={'was_impossible': False}),
#  Prediction(uid=117200, iid=7071, r_ui=4.0, est=3.883483424167373, details={'was_impossible': False}),
#  Prediction(uid=10092, iid=170959, r_ui=4.0, est=3.574473854658882, details={'was_impossible': False}),
#  Prediction(uid=80267, iid=4725, r_ui=5.0, est=3.5755462569427934, details={'was_impossible': False}),
#  Prediction(uid=94288, iid=1197, r_ui=0.5, est=4.091061279447273, details={'was_impossible': False}),
#  Prediction(uid=243960, iid=3, r_ui=2.5, est=3.305658827619039, details={'was_impossible': False}),
#  Prediction(uid=228523, iid=2023, r_ui=4.0, est=3.246069753637236, details={'was_impossible': False}),
#  Prediction(uid=80828, iid=1274, r_ui=4.0, est=3.7293819073266263, details={'was_impossible': False}),
#  Prediction(uid=187997, iid=5952, r_ui=5.0, est=4.0586001553134, details={'was_impossible': False}),
#  Prediction(uid=274299, iid=7153, r_ui=4.5, est=4.0268188667606415, details={'was_impossible': False}),
#  Prediction(uid=302303, iid=202439, r_ui=4.5, est=4.340167410512734, details={'was_impossible': False}),
#  Prediction(uid=160249, iid=5010, r_ui=3.0, est=3.7185404376394344, details={'was_impossible': False}),
#  ...]

# %%
pp = pd.DataFrame(svd_predictions)
pp
# Out:
#           uid    iid  r_ui       est                    details
# 0      320615    457   4.0  3.954320  {'was_impossible': False}
# 1       85899  48516   4.0  3.974727  {'was_impossible': False}
# 2       16521   4896   3.5  3.410295  {'was_impossible': False}
# 3      199688  67255   4.5  3.551359  {'was_impossible': False}
# 4      274004   1672   4.0  3.725641  {'was_impossible': False}
# ...       ...    ...   ...       ...                        ...
# 19995  243459    513   2.0  3.505424  {'was_impossible': False}
# 19996   82623  72369   3.5  3.547431  {'was_impossible': False}
# 19997    1011  56511   3.0  3.544489  {'was_impossible': False}
# 19998  226523    318   5.0  4.462517  {'was_impossible': False}
# 19999  281002   1258   5.0  4.063330  {'was_impossible': False}
#
# [20000 rows x 5 columns]

# %%
pp['uid'].value_counts()
# Out:
# uid
# 189614    19
# 76618     12
# 207216     9
# 233891     8
# 186916     8
#           ..
# 269108     1
# 5133       1
# 154915     1
# 110478     1
# 281002     1
# Name: count, Length: 17352, dtype: int64

# %%
def get_top_n_recommendations(predictions, n=5):
    # Build a dictionary of predictions for each user
    top_n = {}
    for uid, iid, true_r, est, _ in predictions:
        if uid not in top_n:
            top_n[uid] = []
        top_n[uid].append((iid, est))

    # Now sort the predictions for each user and get the n highest rated items
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

# %%
testset_full = trainset.all_items()  # This will contain all movieId items
predictions_svd = [svd.predict(uid, iid) for uid in df_sample['userId'] for iid in testset_full]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[87], line 2
#       1 testset_full = trainset.all_items()  # This will contain all movieId items
# ----> 2 predictions_svd = [svd.predict(uid, iid) for uid in df_sample['userId'] for iid in testset_full]
#
# File /opt/anaconda3/envs/mylearnenv/lib/python3.12/site-packages/surprise/prediction_algorithms/algo_base.py:96, in AlgoBase.predict(self, uid, iid, r_ui, clip, verbose)
#      94     iuid = "UKN__" + str(uid)
#      95 try:
# ---> 96     iiid = self.trainset.to_inner_iid(iid)
#      97 except ValueError:
#      98     iiid = "UKN__" + str(iid)
#
# File /opt/anaconda3/envs/mylearnenv/lib/python3.12/site-packages/surprise/trainset.py:139, in Trainset.to_inner_iid(self, riid)
#     136     except KeyError:
#     137         raise ValueError(str(iuid) + " is not a valid inner id.")
# --> 139 def to_inner_iid(self, riid):
#     140     """Convert an **item** raw id to an inner id.
#     141
#     142     See :ref:`this note<raw_inner_note>`.
#    (...)
#     151         ValueError: When item is not part of the trainset.
#     152     """
#     154     try:
#
# KeyboardInterrupt:

# %%
svd.predict(238308, 5995)
# Out:
# Prediction(uid=238308, iid=5995, r_ui=None, est=4.2042869794098925, details={'was_impossible': False})

# %%
top_n_svd = get_top_n_recommendations(svd_predictions, n=5)

# %%
user_id = 207216
print(f"Top 5 recommendations for user {user_id} using SVD:")
for iid, rating in top_n_svd[user_id]:
    print(f"MovieId: {iid}, Predicted Rating: {rating:.2f}")
# Out:
# Top 5 recommendations for user 207216 using SVD:
# MovieId: 2183, Predicted Rating: 3.79
# MovieId: 8502, Predicted Rating: 3.39
# MovieId: 67068, Predicted Rating: 3.39
# MovieId: 53554, Predicted Rating: 3.39
# MovieId: 4418, Predicted Rating: 3.39

# %%
MovieId: 84189, Predicted Rating: 3.30
MovieId: 90071, Predicted Rating: 3.14
MovieId: 105855, Predicted Rating: 3.14
MovieId: 151453, Predicted Rating: 3.14
MovieId: 163839, Predicted Rating: 3.14

# %%
# top_n_recommendations = get_top_n_recommendations(svd_predictions, n=5)

# %%
# user_id = 192762
# top_5_for_user = top_n_recommendations.get(user_id, [])
# print(f"Top 5 recommendations for user {user_id}:")
# for movie_id, est_rating in top_5_for_user:
#     print(f"Movie ID: {movie_id}, Predicted Rating: {est_rating:.2f}")
# Out:
# Top 5 recommendations for user 192762:
# Movie ID: 19, Predicted Rating: 3.25

# %% [markdown]
# -------------------------------------

# %%
user_id = 190105
movie_id = 1544

# %%
svd_prediction = svd.predict(user_id, movie_id)
print(f"SVD prediction for user {user_id} and movie {movie_id}: {svd_prediction.est:.2f}")

# %%
svdpp_prediction = svdpp.predict(user_id, movie_id)
print(f"SVD++ prediction for user {user_id} and movie {movie_id}: {svdpp_prediction.est:.2f}")

# %%
# Combine SVD and SVD++ predictions (simple average)
def ensemble_predictions(pred_svd, pred_svdpp):
    return (pred_svd.est + pred_svdpp.est) / 2

# Get predictions for the same user and movie
ensemble_prediction = ensemble_predictions(svd_prediction, svdpp_prediction)
print(f"Ensemble prediction for user {user_id} and movie {movie_id}: {ensemble_prediction:.2f}")

# %% [markdown]
# --------------

# %%
def get_top_n(predictions, n=5):
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Sort the predictions for each user and retrieve the top N
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]
        
    return top_n

# %%
# Generate predictions for all user-item pairs
testset_full = trainset.all_items()  # This will contain all movieId items
predictions_svd = [svd.predict(uid, iid) for uid in df['userId'].unique() for iid in testset_full]

# %%
# Get top 5 recommendations for each user
# top_n_svd = get_top_n(predictions_svd, n=5)

# %%
# user_id = 138297
# print(f"Top 5 recommendations for user {user_id} using SVD:")
# for iid, rating in top_n_svd[user_id]:
#     print(f"MovieId: {iid}, Predicted Rating: {rating:.2f}")

# %%
# mae = accuracy.mae(svd_prediction)
